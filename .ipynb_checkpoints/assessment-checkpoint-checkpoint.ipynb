# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("E:\coding\python\winedataset\WineQT.csv")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
na_df = data[data.isna().any(axis = 1)]
na_df.head()
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality, Id]
# Index: []

# %%
data.shape
# Out:
# (1143, 13)

# %%
s= list(data)
s
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality',
#  'Id']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
data['pH'].unique()
# Out:
# array([3.51, 3.2 , 3.26, 3.16, 3.3 , 3.39, 3.36, 3.28, 3.58, 3.04, 3.52,
#        3.17, 3.43, 3.34, 3.47, 3.38, 3.35, 3.4 , 3.42, 3.23, 3.33, 3.21,
#        3.9 , 3.25, 3.15, 3.41, 3.44, 3.31, 3.54, 2.93, 3.14, 3.48, 3.75,
#        3.45, 3.29, 3.08, 3.46, 3.19, 3.32, 3.07, 3.49, 3.53, 3.24, 3.63,
#        3.22, 3.68, 2.74, 3.59, 3.37, 3.12, 3.57, 3.11, 3.  , 3.61, 3.06,
#        3.6 , 3.69, 3.1 , 3.05, 3.67, 3.27, 3.13, 3.02, 3.18, 3.55, 2.99,
#        3.56, 3.62, 2.88, 2.95, 3.5 , 2.98, 3.03, 3.09, 2.86, 3.74, 2.92,
#        3.72, 2.89, 2.94, 3.66, 3.71, 3.01, 3.78, 3.7 , 4.01, 2.9 ])

# %%
data.pH.value_counts().sort_index()
# Out:
# pH
# 2.74    1
# 2.86    1
# 2.88    2
# 2.89    3
# 2.90    1
#        ..
# 3.74    1
# 3.75    1
# 3.78    2
# 3.90    2
# 4.01    2
# Name: count, Length: 87, dtype: int64

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# fixed acidity             2.000000
# volatile acidity          0.247500
# citric acid               0.330000
# residual sugar            0.700000
# chlorides                 0.020000
# free sulfur dioxide      14.000000
# total sulfur dioxide     40.000000
# density                   0.002275
# pH                        0.195000
# sulphates                 0.180000
# alcohol                   1.600000
# quality                   1.000000
# Id                      798.500000
# dtype: float64

# %%
data.corr()['pH']
# Out:
# fixed acidity          -0.685163
# volatile acidity        0.221492
# citric acid            -0.546339
# residual sugar         -0.116959
# chlorides              -0.277759
# free sulfur dioxide     0.072804
# total sulfur dioxide   -0.059126
# density                -0.352775
# pH                      1.000000
# sulphates              -0.185499
# alcohol                 0.225322
# quality                -0.052453
# Id                      0.132904
# Name: pH, dtype: float64

# %%
plt.figure(dpi = 130)
sns.heatmap(data.corr(), annot = True,fmt = '.2f', annot_kws = {"fontsize":8})
plt.show()

# %%
if (data['fixed acidity'].shape == data['volatile acidity'].shape == data['citric acid'].shape == data['residual sugar'].shape == data.chlorides.shape == data['free sulfur dioxide'].shape == data['total sulfur dioxide'].shape == data.density.shape == data.pH.shape == data.sulphates.shape == data.alcohol.shape == data.quality.shape == data.Id.shape):
    print("proceed futher")
else:
    print("error")
# Out:
# proceed futher

# %%
fig, plot = plt.subplots(13, figsize = (5, 5))
plt1 = sns.boxplot(data['fixed acidity'], ax = plot[0])
plt1 = sns.boxplot(data['volatile acidity'], ax = plot[1])
plt1 = sns.boxplot(data['citric acid'], ax = plot[2])
plt1 = sns.boxplot(data['residual sugar'], ax = plot[3])
plt1 = sns.boxplot(data['chlorides'], ax = plot[4])
plt1 = sns.boxplot(data['free sulfur dioxide'], ax = plot[5])
plt1 = sns.boxplot(data['total sulfur dioxide'], ax = plot[6])
plt1 = sns.boxplot(data['density'], ax = plot[7])
plt1 = sns.boxplot(data['pH'], ax = plot[8])
plt1 = sns.boxplot(data['sulphates'], ax = plot[9])
plt1 = sns.boxplot(data['alcohol'], ax = plot[10])
plt1 = sns.boxplot(data['quality'], ax = plot[11])
plt1 = sns.boxplot(data['Id'], ax = plot[12])
plt.tight_layout()
# Out:
# C:\Users\sasha\AppData\Local\Temp\ipykernel_8076\2461552495.py:15: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
sns.pairplot(data, x_vars = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density','sulphates','alcohol'], y_vars = 'pH', height  = 5, aspect = 1, kind = "scatter")
plt.show()
# Out:
# E:\appsetup\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >
